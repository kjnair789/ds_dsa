# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
# ...

# %%
import pandas as pd

# %%
data=pd.read_csv("tip.csv")

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# List operations

# %%
l1=list()

# %%
type(l1)
# Out:
# list

# %%
l1.append(10)

# %%
l1
# Out:
# [10]

# %%
l1.append(30)

# %%
l1.append(15)

# %%
l1
# Out:
# [10, 30, 15]

# %%
l1[-2]
# Out:
# 30

# %%
l1.sort()

# %%
l1
# Out:
# [10, 15, 30]

# %%
num=[2,5,1,7,5,10]

# %%
nums=sorted(num)

# %%
nums
# Out:
# [1, 2, 5, 5, 7, 10]

# %%
num
# Out:
# [2, 5, 1, 7, 5, 10]

# %%
names=['krish','athulya','dev']

# %%
names
# Out:
# ['krish', 'athulya', 'dev']

# %%
snames=sorted(names)

# %%
snames
# Out:
# ['athulya', 'dev', 'krish']

# %%
#sort names based on length

# %%
lnames=sorted(names,key=len)

# %%
lnames
# Out:
# ['dev', 'krish', 'athulya']

# %%
lnames=sorted(names,key=len,reverse=True)

# %%
lnames
# Out:
# ['athulya', 'krish', 'dev']

# %%
n=[ 2**i for i in range(0,9)]
n[0]=0

# %%
n
# Out:
# [0, 2, 4, 8, 16, 32, 64, 128, 256]

# %%
#[1,3,5,7,9]

# %%
oddnum=[i for i in range(1,10) if i%2==1]

# %%
oddnum
# Out:
# [1, 3, 5, 7, 9]

# %%
#remove duplicate [2,3,4,5,6,7]

# %%
lm=[2,3,4,5,2,6,7]

# %%
m=[]

# %%
for i in lm:
    if i not in m:
        m.append(i)

# %%
m
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
rm=[2,3,4,5,6,7]

# %%
rm[::-1]
# Out:
# [7, 6, 5, 4, 3, 2]

# %%
rm=[2,3,4,1,5,9]

# %%
#target=5 o/p=[2,3]  target=14 o/p=[5,9] target=6 o/p=[1,5]

# %%
#dictionary   unorderd key value pair

# %%
d={'a':100,'b':200,'c':300}

# %%
d.get('a')
# Out:
# 100

# %%
d.get('d',0)
# Out:
# 0

# %%
d.popitem()  #no need to specify anything
# Out:
# ('c', 300)

# %%
d.pop('a')  #need to specify the element
# Out:
# 100

# %%
d
# Out:
# {'b': 200}

# %%
emp={'id':1000,'name':'joe','salary': 20000}

# %%
emp
# Out:
# {'id': 1000, 'name': 'joe', 'salary': 20000}

# %%
emp.setdefault('id',1200)
# Out:
# 1000

# %%
emp.setdefault('place','Goa')
# Out:
# 'Goa'

# %%
emp
# Out:
# {'id': 1000, 'name': 'joe', 'salary': 20000, 'place': 'Goa'}

# %%
#() tuple immutable

# %%
t1=(1,2,3,4)

# %%
t1[0]
# Out:
# 1

# %%
t2=([1,2,3],[2,4,5])

# %%
t2
# Out:
# ([1, 2, 3], [2, 4, 5])

# %%
t2[1]
# Out:
# [2, 4, 5]

# %%
t2[1][2]
# Out:
# 5

# %%
t2[1][2]=3

# %%
t2
# Out:
# ([1, 2, 3], [2, 4, 3])

# %%
#set mutable  duplicate not allowed{}   no order

# %%
s1={1,3,1,5,4}

# %%
s1
# Out:
# {1, 3, 4, 5}

# %%
l=[2,3,4,4,5,1]   #removed repeated elements in list

# %%
ls=set(l)

# %%
ls
# Out:
# {1, 2, 3, 4, 5}

# %%
s1={1,3,4,5,3,3773,66,4444}

# %%
s1
# Out:
# {1, 3, 4, 5, 66, 3773, 4444}
