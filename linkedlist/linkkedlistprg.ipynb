# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

# %%
n1=Node(10)
n2=Node(200)

# %%
print(n1.data)
# Out:
# 10

# %%
print(n2.data)
# Out:
# 200

# %%
n1.next=n2

# %%
n1.next.data
# Out:
# 200

# %%
n3=Node(300)

# %%
n2.next=n3

# %%
cur=n1
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# 10
# 200
# 300

# %%
n4=Node(500)

# %%
n4.next=n1

# %%
n4.next.data
# Out:
# 10

# %%
cur=n4
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# 500
# 10
# 200
# 300

# %%
n5=Node(20)

# %%
n3.next=n5

# %%
n3.next.data
# Out:
# 20

# %%
cur=n4
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# 500
# 10
# 200
# 300
# 20

# %%
n3.next=None

# %%
cur=n4
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# 500
# 10
# 200
# 300

# %%
n4.next=None

# %%
cur=n1
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# 10
# 200
# 300

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

# %%
n1=Node(10)
n2=Node(20)
n3=Node(30)
n4=Node(40)

# %%
n1.next=n2
n2.next=n3
n3.next=n4
n4.next=None

# %%
s=0
cur=n1
while cur:
    s=s+cur.data
    cur=cur.next

# %%
print(s)
# Out:
# 100

# %%
print(max)
# Out:
# 40

# %%
rev=[]
cur=n1
while cur:
    rev.insert(0,cur.data)
    cur=cur.next
print(rev)
# Out:
# [40, 30, 20, 10]

# %%
class Student:
    def __init__(self,id,name,result):
        self.id=id
        self.name=name
        self.result=result
        self.next=None
    def student_info(self):
        print(f"Studentid:{self.id} Studentname:{self.name} Studentresult:{self.result}")

# %%
n=int(input("enter no.of students:"))
students=[]
# Out:
# enter no.of students: 3

# %%
for i in range(n):
    id=int(input("enter student id"))
    name=input("enter student name")
    result=input("enter student result")
    s1=Student(id,name,result)
    students.append(s1)
# Out:
# enter student id 101
# enter student name riya
# enter student result pass
# enter student id 102
# enter student name miya
# enter student result pass
# enter student id 103
# enter student name anu
# enter student result fail

# %%
print("student details")
for s in students:
    s.student_info()
# Out:
# student details
# Studentid:101 Studentname:riya Studentresult:pass
# Studentid:102 Studentname:miya Studentresult:pass
# Studentid:103 Studentname:anu Studentresult:fail

# %%
li=[1,20,15,14,"anu"]
id,*marks,name=li

# %%
marks
# Out:
# [20, 15, 14]

# %%
name
# Out:
# 'anu'

# %%
id
# Out:
# 1
